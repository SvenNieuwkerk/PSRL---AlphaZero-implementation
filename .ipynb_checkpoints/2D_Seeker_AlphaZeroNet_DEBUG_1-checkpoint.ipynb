# %% [markdown]
# # Imports, device and seeding

# %%
# --- Standard libs ---
import os
import math
import random
from dataclasses import dataclass
from typing import Dict, Any
import pickle

# --- Scientific stack ---
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# --- ACORL and RL ---
from acorl.envs.seeker.seeker import SeekerEnv, SeekerEnvConfig

# --- Own Code ---
from MCTS import MCTSPlanner
from network import SeekerAlphaZeroNet
from utils import (
    ReplayBufferHybrid,
    collect_one_episode_hybrid,
    train_step_mle,
    train_step_mcts_distill,
    train_step_hybrid,
    run_eval_episodes,
    run_debug_eval_episode,
)

# --- Device ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)


# --- Reproducibility ---
def set_global_seeds(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


SEED = 42
set_global_seeds(SEED)
# Out:
# Using device: cpu

# %% [markdown]
# # Config

# %% [markdown]
# ## baseline config
# ### Comments are explaining what each parameter does in general, but also mixed with comments that explain behavious of this specific configuration

# %%
@dataclass
class Config:
    # ========================
    # Environment
    # ========================
    max_episode_steps: int = 200

    # ========================
    # MCTS core
    # ========================
    num_simulations: int = 200    # Number of MCTS simulations per real environment step
    cpuct: float = 1.5            # Exploration vs exploitation tradeoff in PUCT; Higher -> more exploration guided by policy prior
    gamma: float = 0.99           # Discount factor for return backup in MCTS
    max_depth: int = 64           # Safety cap on tree depth during a simulation

    # For root action selection / Action sampling temperature at root
    # >1.0 = more stochastic, 1.0 = proportional to visits, ~0 = greedy
    temperature: float = 1.0

    # ========================
    # Progressive Widening
    # ========================
    pw_k: float = 2.0
    # Controls how many actions are allowed per node:
    #   K_max = pw_k * N(s)^pw_alpha
    pw_alpha: float = 0.5
    # Growth rate of branching factor
    # 0.5 is common; smaller = more conservative expansion

    # ========================
    # Action sampling (baseline, non-fancy, but no duplicates)
    # ========================
    # --- Uniform warmstart ---
    # No uniform warmstart, no diversity scoring
    K_uniform_per_node: int = 8
    # First K children per node are sampled uniformly in [-1,1]^2
    # Set to 0 to disable
    warmstart_iters: int = 20
    # Number of *training iterations* during which ALL nodes use uniform sampling
    # 0 disables global warmstart; use this if you want uniform sampling only early in training

    # --- Novelty reject (hard deduplication) ---
    # Deduplicate actions (keep this ON to satisfy “no duplicate actions”)
    novelty_eps: float = 1e-3      # small but > 0
    # Minimum distance between actions to be considered "new"
    # In [-1,1]^2, values around 0.05–0.15 are reasonable
    # Set <=0 to disable
    novelty_metric: str = "l2"
    # Distance metric for novelty check:
    # "linf" = max(|dx|, |dy|)  (good for box action spaces)
    # "l2"   = Euclidean distance

    # --- Diversity scoring (soft repulsion) ---
    # Disable candidate scoring / diversity
    num_candidates: int = 1
    # Number of candidate actions sampled before choosing the best
    # <=1 disables diversity scoring
    diversity_lambda: float = 0.0
    # Strength of diversity penalty
    # Higher -> stronger push away from already-sampled actions
    # Set <=0 to disable
    diversity_sigma: float = 0.25  # unused
    # Length scale for diversity penalty
    # Roughly: how far actions must be before they stop "repelling" each other
    policy_beta: float = 1.0       # unused
    # Weight of policy log-probability in candidate scoring
    # Higher -> follow policy more closely
    # Lower -> prioritize diversity more

    # --- Resampling control ---
    max_resample_attempts: int = 16
    # How many times expansion may retry to find a novel action
    # If all fail, expansion is declined and MCTS falls back to selection
    
    # ========================
    # Training
    # ========================
    batch_size: int = 128
    learning_rate: float = 3e-4
    weight_decay: float = 1e-4
    train_steps_per_iter: int = 200    # Gradient updates per outer iteration

    # (Only used by our baseline loss function)
    value_loss_weight: float = 1.0
    policy_loss_weight: float = 1.0  # applies to mu/log_std regression

    # ========================
    # Data collection
    # ========================
    episodes_per_iter: int = 10     # Number of real env episodes collected per training iteration
    replay_buffer_capacity: int = 50_000

    # ========================
    # Logging / evaluation
    # ========================
    eval_every: int = 5
    eval_episodes: int = 10   # use 10 fixed seeds for smoother eval curves


cfg = Config()

# %% [markdown]
# ## Sanity test

# %%
from pprint import pprint
pprint(cfg)
# Out:
# Config(max_episode_steps=200,
#        num_simulations=200,
#        cpuct=1.5,
#        gamma=0.99,
#        max_depth=64,
#        temperature=1.0,
#        pw_k=2.0,
#        pw_alpha=0.5,
#        K_uniform_per_node=8,
#        warmstart_iters=20,
#        novelty_eps=0.001,
#        novelty_metric='l2',
#        num_candidates=1,
#        diversity_lambda=0.0,
#        diversity_sigma=0.25,
#        policy_beta=1.0,
#        max_resample_attempts=16,
#        batch_size=128,
#        learning_rate=0.0003,
#        weight_decay=0.0001,
#        train_steps_per_iter=200,
#        value_loss_weight=1.0,
#        policy_loss_weight=1.0,
#        episodes_per_iter=10,
#        replay_buffer_capacity=50000,
#        eval_every=5,
#        eval_episodes=10)

# %% [markdown]
# # Create env_real, env_sim, dims (for network), and step_fn (for MCTSPlanner)

# %%
EVAL_SEEDS = list(range(1000, 1000 + cfg.eval_episodes))  # fixed "validation set"

# --- Env config ---
env_config = SeekerEnvConfig(randomize=True, num_obstacles=1)

# --- Real environment for rollouts / data collection ---
env_real = SeekerEnv(**env_config.model_dump(exclude={"id"}))
obs0, info0 = env_real.reset()

obs_dim = env_real.observation_space.shape[0]
action_dim = env_real.action_space.shape[0]

print("obs_dim:", obs_dim, "action_dim:", action_dim)
print("action_space:", env_real.action_space)

# --- Simulation environment for MCTS step_fn ---
env_sim = SeekerEnv(**env_config.model_dump(exclude={"id"}))

# --- evaluation environment for evaluation during training ---
env_eval = SeekerEnv(**env_config.model_dump(exclude={"id"}))


def set_env_state_from_obs(sim_env: SeekerEnv, obs: np.ndarray):
    """
    Overwrite SeekerEnv internal state to match the flat observation vector.

    obs layout (from your old notebook):
      [agent_x, agent_y, goal_x, goal_y, (obs_x, obs_y, obs_r)*N]
    """
    obs = np.asarray(obs, dtype=sim_env._dtype)

    # agent and goal
    sim_env._agent_position = obs[0:2].copy()
    sim_env._goal_position = obs[2:4].copy()

    # obstacles
    obstacles = obs[4:].reshape(-1, 3)
    sim_env._obstacle_position = obstacles[:, 0:2].copy()
    sim_env._obstacle_radius = obstacles[:, 2].copy()

def step_fn(state: np.ndarray, action: np.ndarray):
    """
    MCTS transition function: set env_sim to `state`, take `action`, return next_state/reward/done/info.
    Returns: next_state, reward, done, info  (matching MCTSPlanner expectations)
    """
    set_env_state_from_obs(env_sim, state)

    action = np.asarray(action, dtype=env_sim._dtype)
    next_obs, reward, terminated, truncated, info = env_sim.step(action)
    done = bool(terminated or truncated)

    return next_obs, float(reward), done, info
# Out:
# obs_dim: 7 action_dim: 2
# action_space: Box(-1.0, 1.0, (2,), float64)

# %% [markdown]
# # Instantiate neural network and optimizer

# %%
# --- Network ---
net = SeekerAlphaZeroNet(obs_dim=obs_dim, action_dim=action_dim).to(device)

# Optional: print one forward pass sanity
obs_t = torch.from_numpy(obs0).float().unsqueeze(0).to(device)
with torch.no_grad():
    mu_t, log_std_t, v_t = net(obs_t)

print("mu:", mu_t.cpu().numpy())
print("log_std:", log_std_t.cpu().numpy())
print("v:", v_t.item())

# --- Optimizer (we'll use later) ---
optimizer = optim.AdamW(net.parameters(), lr=cfg.learning_rate, weight_decay=cfg.weight_decay)
# Out:
# mu: [[-0.26337135 -0.13172348]]
# log_std: [[ 0.45294833 -0.14332369]]
# v: 0.02973608300089836

# %% [markdown]
# # Instantiate MCTSPlanner

# %%
planner = MCTSPlanner(
    net=net,
    device=str(device),
    step_fn=step_fn,
    num_simulations=cfg.num_simulations,
    cpuct=cfg.cpuct,
    gamma=cfg.gamma,
    pw_k=cfg.pw_k,
    pw_alpha=cfg.pw_alpha,
    max_depth=cfg.max_depth,
    temperature=cfg.temperature,
    rng=np.random.default_rng(SEED),
    
    K_uniform_per_node=cfg.K_uniform_per_node,
    warmstart_iters=cfg.warmstart_iters,
    novelty_eps=cfg.novelty_eps,
    novelty_metric=cfg.novelty_metric,
    num_candidates=cfg.num_candidates,
    diversity_lambda=cfg.diversity_lambda,
    diversity_sigma=cfg.diversity_sigma,
    policy_beta=cfg.policy_beta,
    max_resample_attempts=cfg.max_resample_attempts,
)

# %% [markdown]
# # Smoke test: one MCTS search, inspect root, pick action, step env_real

# %%
# Reset real env
obs, info = env_real.reset()

# Run one MCTS search from the current observation
root = planner.search(obs)

print("Root visit count N:", root.N)
print("Root children K:", len(root.children))

# Show a few children stats
for i, ch in enumerate(root.children[:5]):
    print(
        f"[{i}] N_sa={ch.N_sa:4d}  Q_sa={ch.Q_sa:+.4f}  "
        f"P_raw={ch.P_sa_raw:.3e}  P={ch.P_sa:.3f}  action={ch.action}"
    )

# Pick an action from MCTS policy (training=True samples from visit counts)
action = planner.act(root, training=True)
print("Chosen action:", action)

# Step the real environment once
next_obs, reward, terminated, truncated, info = env_real.step(action)
done = bool(terminated or truncated)

print("Step result -> reward:", reward, "done:", done)
print("Obs delta L2:", np.linalg.norm(next_obs - obs))
# Out:
# Root visit count N: 200
# Root children K: 29
# [0] N_sa=   5  Q_sa=-21.3346  P_raw=1.123e-01  P=0.044  action=[ 0.5479121  -0.12224312]
# [1] N_sa=   3  Q_sa=-33.9120  P_raw=8.752e-02  P=0.035  action=[0.71719587 0.39473605]
# [2] N_sa=   4  Q_sa=-2.7142  P_raw=4.341e-02  P=0.017  action=[-0.8116453  0.9512447]
# [3] N_sa=   6  Q_sa=-17.9681  P_raw=7.721e-02  P=0.031  action=[0.5222794 0.5721286]
# [4] N_sa=  11  Q_sa=-2.6866  P_raw=5.583e-02  P=0.022  action=[-0.25840396  0.85353   ]
# Chosen action: [-0.06088838 -0.6210573 ]
# Step result -> reward: -0.9035175975254326 done: False
# Obs delta L2: 0.6240348783470926

# %%
# Show all children stats
for i, ch in enumerate(root.children):
    print(
        f"[{i}] N_sa={ch.N_sa:4d}  Q_sa={ch.Q_sa:+.4f}  "
        f"P_raw={ch.P_sa_raw:.3e}  P={ch.P_sa:.3f}  action={ch.action}"
    )

actions = np.stack([ch.action for ch in root.children], axis=0)
print("unique rows:", np.unique(actions, axis=0).shape[0], " / ", actions.shape[0])
# Out:
# [0] N_sa=   5  Q_sa=-21.3346  P_raw=1.123e-01  P=0.044  action=[ 0.5479121  -0.12224312]
# [1] N_sa=   3  Q_sa=-33.9120  P_raw=8.752e-02  P=0.035  action=[0.71719587 0.39473605]
# [2] N_sa=   4  Q_sa=-2.7142  P_raw=4.341e-02  P=0.017  action=[-0.8116453  0.9512447]
# [3] N_sa=   6  Q_sa=-17.9681  P_raw=7.721e-02  P=0.031  action=[0.5222794 0.5721286]
# [4] N_sa=  11  Q_sa=-2.6866  P_raw=5.583e-02  P=0.022  action=[-0.25840396  0.85353   ]
# [5] N_sa=  21  Q_sa=-2.6812  P_raw=1.026e-01  P=0.041  action=[-0.1131716 -0.5455226]
# [6] N_sa=   2  Q_sa=-50.0328  P_raw=1.100e-01  P=0.044  action=[ 0.5161755  -0.29094806]
# [7] N_sa=   6  Q_sa=-18.4197  P_raw=7.088e-02  P=0.028  action=[-0.066558  -0.9123925]
# [8] N_sa=  17  Q_sa=-8.2274  P_raw=9.686e-02  P=0.038  action=[-0.06088838 -0.6210573 ]
# [9] N_sa=   2  Q_sa=-50.1219  P_raw=1.090e-01  P=0.043  action=[ 0.4005302  -0.37526673]
# [10] N_sa=   9  Q_sa=-12.9035  P_raw=9.534e-02  P=0.038  action=[0.5738488  0.32970172]
# [11] N_sa=  16  Q_sa=-2.6647  P_raw=8.523e-02  P=0.034  action=[0.13047221 0.5299977 ]
# [12] N_sa=   4  Q_sa=-2.9716  P_raw=9.780e-02  P=0.039  action=[-0.88339454 -0.43723223]
# [13] N_sa=  10  Q_sa=-12.1164  P_raw=1.144e-01  P=0.045  action=[ 0.4447187  -0.07624554]
# [14] N_sa=   3  Q_sa=-34.0879  P_raw=8.469e-02  P=0.034  action=[0.8171614  0.39941427]
# [15] N_sa=   4  Q_sa=-2.8131  P_raw=6.502e-02  P=0.026  action=[-0.64645445  0.7132286 ]
# [16] N_sa=   3  Q_sa=-2.9718  P_raw=5.313e-02  P=0.021  action=[-0.6588141   0.85024023]
# [17] N_sa=  10  Q_sa=-12.2138  P_raw=1.162e-01  P=0.046  action=[-0.336862    0.04134481]
# [18] N_sa=   9  Q_sa=-13.1673  P_raw=1.171e-01  P=0.046  action=[ 0.10970494 -0.25815544]
# [19] N_sa=   5  Q_sa=-21.2414  P_raw=1.133e-01  P=0.045  action=[ 0.03771672 -0.3681419 ]
# [20] N_sa=   7  Q_sa=-16.3163  P_raw=8.909e-02  P=0.035  action=[ 0.00148237 -0.712205  ]
# [21] N_sa=  10  Q_sa=-12.2555  P_raw=4.983e-02  P=0.020  action=[0.32572842 0.91124654]
# [22] N_sa=   7  Q_sa=-16.2512  P_raw=6.599e-02  P=0.026  action=[0.21203165 0.7354779 ]
# [23] N_sa=   6  Q_sa=-18.7465  P_raw=8.878e-02  P=0.035  action=[-0.43055984 -0.6927732 ]
# [24] N_sa=   1  Q_sa=-100.0000  P_raw=6.595e-02  P=0.026  action=[ 0.6669171  -0.89607626]
# [25] N_sa=   6  Q_sa=-18.4514  P_raw=1.138e-01  P=0.045  action=[-0.2672151  -0.34500888]
# [26] N_sa=   7  Q_sa=-2.7304  P_raw=4.694e-02  P=0.019  action=[-0.72518414  0.9177605 ]
# [27] N_sa=   3  Q_sa=-34.2580  P_raw=9.498e-02  P=0.038  action=[0.5486428  0.34246284]
# [28] N_sa=   3  Q_sa=-2.5561  P_raw=1.038e-01  P=0.041  action=[-0.9753946  -0.09136408]
# unique rows: 29  /  29

# %% [markdown]
# # Tests

# %% [markdown]
# ## plotting functions

# %%
def decode_obs(obs):
    obs = np.asarray(obs)
    agent = obs[0:2]
    goal = obs[2:4]
    obstacles_flat = obs[4:]
    num_obstacles = len(obstacles_flat)//3
    obstacles = obstacles_flat.reshape(num_obstacles, 3)  # (x, y, r) per obstacle
    return agent, goal, obstacles

def plot_seeker_obs(obs, info, title=None):
    agent, goal, obstacles = decode_obs(obs)
    L = info.get("boundary_size", 10)

    fig, ax = plt.subplots(figsize=(6, 6))

    # Obstacles
    for (ox, oy, r) in obstacles:
        circ = plt.Circle((ox, oy), r, color="red", alpha=0.3)
        ax.add_patch(circ)

    # Goal
    ax.scatter(goal[0], goal[1], color="green", s=80, label="Goal")
    # (optional: draw goal radius if you know it somewhere else)

    # Agent
    ax.scatter(agent[0], agent[1], color="blue", s=80, label="Seeker")

    ax.set_xlim(-L, L)
    ax.set_ylim(-L, L)
    ax.set_aspect("equal", adjustable="box")
    ax.legend()
    if title:
        ax.set_title(title)
    plt.show()

# %% [markdown]
# ## Test randomization seed (reproducibility)

# %%
# number of obstacles this env actually has:
num_obstacles = (len(obs) - 4) // 3
# also just env._num_obstacles (?)

# reset real env
obs, info = env_real.reset()
plot_seeker_obs(obs, info, num_obstacles)

# randomize=True should give different positions over next two plots, but always same due to numpy rng seed

# %%
print(obs)
# Out:
# [ 5.98396753 -5.17789601 -5.72715059 -5.69871882  0.58691692 -5.41791639
#   2.52576318]

# %%
# should be:
# [ 5.98396753 -5.17789601 -5.72715059 -5.69871882  0.58691692 -5.41791639
#   2.52576318]
obs == [5.98396753, -5.17789601, -5.72715059, -5.69871882, 0.58691692, -5.41791639, 2.52576318]
# Out:
# array([False, False, False, False, False, False, False])

# %%
# reset real env -> different setup, but same different every time notebook is restarted ?
obs, info = env_real.reset()
plot_seeker_obs(obs, info, num_obstacles)

# randomize=True should give different positions over next two plots, but always same due to numpy rng seed

# %%
print(obs)
# Out:
# [-1.22498966 -3.75787548 -0.79074028  5.13316731 -1.03394827  0.15360326
#   2.01160903]

# %%
# should be:
# [-1.22498966 -3.75787548 -0.79074028  5.13316731 -1.03394827  0.15360326
#   2.01160903]
obs == [-1.22498966, -3.75787548, -0.79074028, 5.13316731, -1.03394827, 0.15360326, 2.01160903]
# FAILS DUE TO ACTUALLY obs[0] (as an example) BEING -1.2249896644419165
# Out:
# array([False, False, False, False, False, False, False])

# %% [markdown]
# # create buffer, collect data, train, and log losses

# %% [markdown]
# ## buffer and logging containers; schedules

# %%
# Buffer
replay = ReplayBufferHybrid(
    capacity=cfg.replay_buffer_capacity,
    obs_dim=obs_dim,
    action_dim=action_dim,
    K_max=32,
)

# Logging containers (easy to plot later)
logs = {
    "loss_total": [],
    "loss_value": [],
    "loss_policy": [],
    "loss_policy_distill": [],
    "loss_mu": [],
    "loss_log_std": [],
    "ep_return": [],
    "ep_length": [],
    "eval_return_mean": [],
    "eval_return_std": [],
    "eval_length_mean": [],
    "success_rate": [],
    "collision_rate": [],
    "iter_idx_eval": [],
}

# %% [markdown]
# # Training OVERFIT FOR DEBUGGING

# %%
DEBUG_DIR = "debug_traces"
os.makedirs(DEBUG_DIR, exist_ok=True)

DEBUG_EVERY = 10          # e.g. every 50 training episodes
DEBUG_SEED = EVAL_SEEDS[-1]            # fixed seed for comparability
DEBUG_RECORD_EVERY = 1    # or 2/5 if trees are big
DEBUG_MAX_STEPS = 200

DEBUG_OBS, _ = env_real.reset(seed=DEBUG_SEED)
print(DEBUG_OBS)
# Out:
# [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]

# %%
import time

num_iters = 300

start_time = time.perf_counter()
print("start")
eval_data = []
SEED = SEED +2
#SEED gives len 200, SEED +2 gives len 37. Only used in planner.

for it in range(num_iters):
    now = time.perf_counter()
    print(f"main loop iter: {it}")
    print(f"time: {now-start_time}")
    last_time = now
    
    planner.set_training_iter(it)

    # ---- DEBUG EVAL EPISODE ----
    set_global_seeds(SEED)
    planner.rng = np.random.default_rng(SEED)
    dbg = run_debug_eval_episode(
            env_eval=env_eval,
            planner=planner,
            seed=DEBUG_SEED,
            max_steps=DEBUG_MAX_STEPS,
            obs=DEBUG_OBS,
        )
    dbg["train_episode"] = it  # handy metadata

    path = os.path.join(DEBUG_DIR, f"trace_ep{it:06d}_seed{DEBUG_SEED}.pkl")
    
    with open(path, "wb") as f:
        pickle.dump(dbg, f)
    
    now = time.perf_counter()
    print("DEBUG time:", now - last_time)
    last_time = now
    
    # ---- Collect ----
    set_global_seeds(SEED)
    planner.rng = np.random.default_rng(SEED)
    stats, roots_collect = collect_one_episode_hybrid(
        env_real=env_real,
        planner=planner,
        replay_buffer=replay,
        max_steps=cfg.max_episode_steps,
        gamma=cfg.gamma,
        training=False,
        obs=DEBUG_OBS,
    )
    now = time.perf_counter()
    print("collect loop time:", now - last_time)
    last_time = now
    print("Stats from collect loop: ", stats)

    # ---- Train (baseline MLE/value regression) ----
    for _ in range(cfg.train_steps_per_iter):
        batch = replay.sample(cfg.batch_size, device=device, rng=np.random.default_rng(SEED))
        loss_dict = train_step_mle(
            net=net,
            optimizer=optimizer,
            batch=batch,
            w_value=cfg.value_loss_weight,
            w_policy=cfg.policy_loss_weight,
            grad_clip_norm=1.0,
        )
        for k, v in loss_dict.items():
            logs[k].append(v)
    now = time.perf_counter()
    print("train loop time:", now - last_time)
    last_time = now
    
        

    last_loss = logs["loss_total"][-1] if logs["loss_total"] else None
    print(
        f"Iter {it} | replay={len(replay)} | "
        #f"train_return_mean={np.mean(ep_returns):.2f} | last_loss={last_loss}"
        f"last_loss={last_loss}"
    )
# Out:
# start
# main loop iter: 0
# time: 0.0004121000001759967
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.0171205000001464
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 2.0078780999997434
# Stats from collect loop:  {'return': 81.74000247308022, 'length': 37, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.39737379999996847
# Iter 0 | replay=37 | last_loss=0.04797546565532684
# main loop iter: 1
# time: 4.423020800000359
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 11.599651499999709
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 10.928524599999946
# Stats from collect loop:  {'return': -192.0141203127383, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.40097910000031334
# Iter 1 | replay=237 | last_loss=0.05952346324920654
# main loop iter: 2
# time: 27.35245490000034
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8397680999996737
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.734770000000026
# Stats from collect loop:  {'return': 85.68387402466774, 'length': 33, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3881029000003764
# Iter 2 | replay=270 | last_loss=0.05893315002322197
# main loop iter: 3
# time: 31.315350000000308
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.4737774000000172
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.857809300000099
# Stats from collect loop:  {'return': 83.32874028204608, 'length': 35, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3982833000000028
# Iter 3 | replay=305 | last_loss=0.04852065071463585
# main loop iter: 4
# time: 36.04548890000024
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 3.29094780000014
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 3.3114329999998517
# Stats from collect loop:  {'return': 59.52417056346468, 'length': 59, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.39736850000008417
# Iter 4 | replay=364 | last_loss=0.056631602346897125
# main loop iter: 5
# time: 43.0457894000001
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 11.704196700000011
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 10.983480599999893
# Stats from collect loop:  {'return': -193.13350012872624, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.3838196000001517
# Iter 5 | replay=564 | last_loss=0.05691402778029442
# main loop iter: 6
# time: 66.11759530000018
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 11.673685600000226
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 11.276035200000024
# Stats from collect loop:  {'return': -193.11324089636466, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.38848589999997785
# Iter 6 | replay=764 | last_loss=0.05910496413707733
# main loop iter: 7
# time: 89.45605290000003
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.0998961000000236
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 2.56004269999994
# Stats from collect loop:  {'return': 80.80704244904923, 'length': 38, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3878614000000198
# Iter 7 | replay=802 | last_loss=0.0564253032207489
# main loop iter: 8
# time: 94.50416280000036
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 12.156000999999833
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 11.502098699999806
# Stats from collect loop:  {'return': -199.3458612980696, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.39183490000004895
# Iter 8 | replay=1002 | last_loss=0.0688895434141159
# main loop iter: 9
# time: 118.55422770000041
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 3.106482799999867
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 2.6448875000000953
# Stats from collect loop:  {'return': 69.75565597190428, 'length': 49, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.40716959999963365
# Iter 9 | replay=1051 | last_loss=0.06032787263393402
# main loop iter: 10
# time: 124.71299620000036
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 12.43577359999972
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 11.518391600000086
# Stats from collect loop:  {'return': -200.5727812138406, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.38378700000021126
# Iter 10 | replay=1251 | last_loss=0.05000028759241104
# main loop iter: 11
# time: 149.05117970000038
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 3.2162970999997924
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 2.746803
# Stats from collect loop:  {'return': 67.55185630110263, 'length': 51, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.37456740000016
# Iter 11 | replay=1302 | last_loss=0.046303994953632355
# main loop iter: 12
# time: 155.38907730000028
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 12.412563699999737
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 11.485185100000308
# Stats from collect loop:  {'return': -192.3585565084835, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.3751236999996763
# Iter 12 | replay=1502 | last_loss=0.05399932712316513
# main loop iter: 13
# time: 179.66225030000032
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.053972700000031
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6639368999999533
# Stats from collect loop:  {'return': 86.66702674433367, 'length': 32, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3950239999999212
# Iter 13 | replay=1534 | last_loss=0.05527820438146591
# main loop iter: 14
# time: 183.77544070000022
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.624666900000193
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5394297999996525
# Stats from collect loop:  {'return': 89.47643920312014, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.39345010000033653
# Iter 14 | replay=1563 | last_loss=0.04700755327939987
# main loop iter: 15
# time: 187.3332529000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.9443489000000227
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.8413422999997238
# Stats from collect loop:  {'return': 84.7325101045771, 'length': 34, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3876660000000811
# Iter 15 | replay=1597 | last_loss=0.05839778482913971
# main loop iter: 16
# time: 191.5068527000003
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 3.575581499999771
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 2.78148340000007
# Stats from collect loop:  {'return': 67.40174334775136, 'length': 51, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.37900630000012825
# Iter 16 | replay=1648 | last_loss=0.05775994062423706
# main loop iter: 17
# time: 198.2432090000002
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.510588600000119
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 2.5872487999999976
# Stats from collect loop:  {'return': 75.07738490441415, 'length': 44, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3924547999999959
# Iter 17 | replay=1692 | last_loss=0.05738769471645355
# main loop iter: 18
# time: 203.73377820000042
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8853787999996712
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.7794303000000582
# Stats from collect loop:  {'return': 86.89581400979452, 'length': 32, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3800538999998935
# Iter 18 | replay=1724 | last_loss=0.054779231548309326
# main loop iter: 19
# time: 207.77889040000036
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.119718799999646
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.8071321000002172
# Stats from collect loop:  {'return': 85.82094067753953, 'length': 33, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3949318999998468
# Iter 19 | replay=1757 | last_loss=0.06366918981075287
# main loop iter: 20
# time: 212.10096520000025
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 12.205282100000204
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 11.51860409999972
# Stats from collect loop:  {'return': -199.88689003451816, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.515101400000276
# Iter 20 | replay=1957 | last_loss=0.057755693793296814
# main loop iter: 21
# time: 236.34028940000053
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.8927108999996562
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.9271212000003288
# Stats from collect loop:  {'return': 89.32277364279916, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.6039541999998619
# Iter 21 | replay=1986 | last_loss=0.05972567945718765
# main loop iter: 22
# time: 241.7643678999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.039506600000095
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.8731545000000551
# Stats from collect loop:  {'return': 90.3083124324701, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.5799881000002642
# Iter 22 | replay=2014 | last_loss=0.05763319507241249
# main loop iter: 23
# time: 246.25735620000023
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8388455000003887
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6943870999994033
# Stats from collect loop:  {'return': 93.4057677376833, 'length': 25, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.5523191000002043
# Iter 23 | replay=2039 | last_loss=0.05679655820131302
# main loop iter: 24
# time: 250.34324320000042
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 3.0076687999999194
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 2.1842996999994284
# Stats from collect loop:  {'return': 84.64003621164005, 'length': 34, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.5222536000001128
# Iter 24 | replay=2073 | last_loss=0.07325422763824463
# main loop iter: 25
# time: 256.0577251999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.9300484000004872
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.76776880000034
# Stats from collect loop:  {'return': 88.07117012168628, 'length': 30, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.49727899999925285
# Iter 25 | replay=2103 | last_loss=0.06465452164411545
# main loop iter: 26
# time: 260.25311590000047
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 3.1927749999995285
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 2.7712264000001596
# Stats from collect loop:  {'return': 69.36791754349386, 'length': 49, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4881044000003385
# Iter 26 | replay=2152 | last_loss=0.06543798744678497
# main loop iter: 27
# time: 266.7055675000006
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 13.454000099999575
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 12.330112499999814
# Stats from collect loop:  {'return': -199.5170303488595, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.5169224999999642
# Iter 27 | replay=2352 | last_loss=0.0698205754160881
# main loop iter: 28
# time: 293.0069550000003
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 12.024606699999822
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 11.532578299999841
# Stats from collect loop:  {'return': -195.08643515819458, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.42397080000046117
# Iter 28 | replay=2552 | last_loss=0.05746719613671303
# main loop iter: 29
# time: 316.9884201
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.7051384000005783
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 2.5301484999999957
# Stats from collect loop:  {'return': 72.7949761827934, 'length': 46, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3909834999994928
# Iter 29 | replay=2598 | last_loss=0.060831718146800995
# main loop iter: 30
# time: 322.6149214000002
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 12.535809099999824
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 11.413310200000524
# Stats from collect loop:  {'return': -197.94736644889554, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.38730129999930796
# Iter 30 | replay=2798 | last_loss=0.07188176363706589
# main loop iter: 31
# time: 346.9516075000006
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8553799999999683
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.4667119999994611
# Stats from collect loop:  {'return': 90.92923422159042, 'length': 27, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3721203000004607
# Iter 31 | replay=2825 | last_loss=0.06779046356678009
# main loop iter: 32
# time: 350.6460466000003
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.7534552999995867
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6577923000004375
# Stats from collect loop:  {'return': 88.2510553382464, 'length': 30, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3910305999997945
# Iter 32 | replay=2855 | last_loss=0.0666409283876419
# main loop iter: 33
# time: 354.44859190000034
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.5021359000002121
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.4098291000000245
# Stats from collect loop:  {'return': 91.26733810151687, 'length': 27, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3920929999994769
# Iter 33 | replay=2882 | last_loss=0.074750155210495
# main loop iter: 34
# time: 357.7529401000006
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.202195599999868
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.4714364999999816
# Stats from collect loop:  {'return': 91.67704431682998, 'length': 27, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3738672999998016
# Iter 34 | replay=2909 | last_loss=0.07279287278652191
# main loop iter: 35
# time: 361.8007091000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.676769499999864
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5903791000000638
# Stats from collect loop:  {'return': 89.9504125980531, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3770402000000104
# Iter 35 | replay=2938 | last_loss=0.07920056581497192
# main loop iter: 36
# time: 365.44517600000063
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.54819150000003
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.655744899999263
# Stats from collect loop:  {'return': 90.88664072384226, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.38667870000062976
# Iter 36 | replay=2966 | last_loss=0.07448475062847137
# main loop iter: 37
# time: 369.0360761000006
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.5966578999996273
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5155131999999867
# Stats from collect loop:  {'return': 89.26774705927636, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.37378720000015164
# Iter 37 | replay=2995 | last_loss=0.07001665979623795
# main loop iter: 38
# time: 372.5222832000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.741027099999883
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.4708107999995264
# Stats from collect loop:  {'return': 90.13659748914726, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.38256950000049983
# Iter 38 | replay=3023 | last_loss=0.07651770114898682
# main loop iter: 39
# time: 376.1170053000001
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6785907000003135
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5932425000000876
# Stats from collect loop:  {'return': 88.42223349675542, 'length': 30, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3842771999998149
# Iter 39 | replay=3053 | last_loss=0.07657651603221893
# main loop iter: 40
# time: 379.77323410000054
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8681001999993896
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6029863000003388
# Stats from collect loop:  {'return': 89.00559243731158, 'length': 30, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.39255539999976463
# Iter 40 | replay=3083 | last_loss=0.05808340013027191
# main loop iter: 41
# time: 383.6371605999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.5113657000001695
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.41427560000011
# Stats from collect loop:  {'return': 91.9102676426957, 'length': 27, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3866360000001805
# Iter 41 | replay=3110 | last_loss=0.08721423149108887
# main loop iter: 42
# time: 386.94966460000023
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.9045482999999876
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.627661000000444
# Stats from collect loop:  {'return': 88.2201241018831, 'length': 30, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3922584999991159
# Iter 42 | replay=3140 | last_loss=0.06975775957107544
# main loop iter: 43
# time: 390.87442130000045
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.5709802999999738
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6568889000000127
# Stats from collect loop:  {'return': 90.3448468248125, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4017186999999467
# Iter 43 | replay=3168 | last_loss=0.06228269264101982
# main loop iter: 44
# time: 394.5042801000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.7578028999996604
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6766606999999567
# Stats from collect loop:  {'return': 87.53944421353141, 'length': 31, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.38514589999977034
# Iter 44 | replay=3199 | last_loss=0.06641200184822083
# main loop iter: 45
# time: 398.32416390000026
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 12.20475449999958
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 11.783764600000723
# Stats from collect loop:  {'return': -196.05786428346406, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.4000650999996651
# Iter 45 | replay=3399 | last_loss=0.07140418887138367
# main loop iter: 46
# time: 422.71304439999994
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.566801800000576
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.4693975000000137
# Stats from collect loop:  {'return': 90.62906671659523, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3835214000000633
# Iter 46 | replay=3427 | last_loss=0.061215274035930634
# main loop iter: 47
# time: 426.1330358
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.571110800000497
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.480982199999744
# Stats from collect loop:  {'return': 90.52136872096075, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.39527579999958107
# Iter 47 | replay=3455 | last_loss=0.05185144767165184
# main loop iter: 48
# time: 429.5806711
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 12.678012200000012
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 11.498895100000482
# Stats from collect loop:  {'return': -196.48602970176762, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.3829707999993843
# Iter 48 | replay=3655 | last_loss=0.08889941871166229
# main loop iter: 49
# time: 454.14079640000045
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8127149000001737
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.7054676999996445
# Stats from collect loop:  {'return': 87.43693285370767, 'length': 31, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3907343000000765
# Iter 49 | replay=3686 | last_loss=0.07240953296422958
# main loop iter: 50
# time: 458.0499537999999
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.3358892000005653
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.707877599999847
# Stats from collect loop:  {'return': 88.10767332177336, 'length': 31, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3997755000000325
# Iter 50 | replay=3717 | last_loss=0.06633417308330536
# main loop iter: 51
# time: 462.49378170000045
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.5333246000000145
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.433657999999923
# Stats from collect loop:  {'return': 91.4570567991437, 'length': 27, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4193349999995917
# Iter 51 | replay=3744 | last_loss=0.0991540476679802
# main loop iter: 52
# time: 465.88037250000025
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 12.404625500000293
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 11.48396049999974
# Stats from collect loop:  {'return': -198.20493217086974, 'length': 200, 'done': False, 'terminated': False, 'truncated': False}
# train loop time: 0.4075126999996428
# Iter 52 | replay=3944 | last_loss=0.07798565924167633
# main loop iter: 53
# time: 490.1767844000001
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6888685000003534
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6049146999994264
# Stats from collect loop:  {'return': 88.30607334108466, 'length': 30, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3830533000000287
# Iter 53 | replay=3974 | last_loss=0.0807763934135437
# main loop iter: 54
# time: 493.8538626000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 4.09878899999967
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 3.331645799999933
# Stats from collect loop:  {'return': 57.723646551255435, 'length': 61, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3991012000005867
# Iter 54 | replay=4035 | last_loss=0.08410750329494476
# main loop iter: 55
# time: 501.6836632999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6595359000002645
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5692268000002514
# Stats from collect loop:  {'return': 89.60646046383035, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3854204999997819
# Iter 55 | replay=4064 | last_loss=0.0996781513094902
# main loop iter: 56
# time: 505.29811720000043
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.9516905000000406
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6304007999997339
# Stats from collect loop:  {'return': 87.85662038448068, 'length': 31, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.38209550000010495
# Iter 56 | replay=4095 | last_loss=0.07986822724342346
# main loop iter: 57
# time: 509.26252800000066
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6407956999992166
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5594209000000774
# Stats from collect loop:  {'return': 89.60979802484192, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.39346690000002127
# Iter 57 | replay=4124 | last_loss=0.07236279547214508
# main loop iter: 58
# time: 512.8565051
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8147047000002203
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5581609000000753
# Stats from collect loop:  {'return': 89.46423015274712, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.41685169999982463
# Iter 58 | replay=4153 | last_loss=0.08363878726959229
# main loop iter: 59
# time: 516.6464541999999
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.658282300000792
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.7355003999991823
# Stats from collect loop:  {'return': 89.27112423503937, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3974167000005764
# Iter 59 | replay=4182 | last_loss=0.0788152664899826
# main loop iter: 60
# time: 520.4379413000001
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6999274999998306
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6113082000001668
# Stats from collect loop:  {'return': 88.62398998465395, 'length': 30, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.39749310000024707
# Iter 60 | replay=4212 | last_loss=0.08662210404872894
# main loop iter: 61
# time: 524.1469231000005
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6494308999999703
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.732473299999583
# Stats from collect loop:  {'return': 89.80425549109145, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.388500699999895
# Iter 61 | replay=4241 | last_loss=0.07630039751529694
# main loop iter: 62
# time: 527.9176049000002
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.7448647000001074
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6509060999997018
# Stats from collect loop:  {'return': 87.84534957124656, 'length': 31, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3712396000000808
# Iter 62 | replay=4272 | last_loss=0.07321509718894958
# main loop iter: 63
# time: 531.6849316000003
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8488907999999356
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5882506999996622
# Stats from collect loop:  {'return': 88.9732460381699, 'length': 30, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.39891440000064904
# Iter 63 | replay=4302 | last_loss=0.08851352334022522
# main loop iter: 64
# time: 535.5212714000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.811095099999875
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.8756690000000162
# Stats from collect loop:  {'return': 86.67502877402781, 'length': 32, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4015729000002466
# Iter 64 | replay=4334 | last_loss=0.10675285011529922
# main loop iter: 65
# time: 539.6098803999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.624899300000834
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5336328999992475
# Stats from collect loop:  {'return': 90.21115018611617, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.40220469999985653
# Iter 65 | replay=4362 | last_loss=0.08569981902837753
# main loop iter: 66
# time: 543.1708503000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.5820267999997668
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6903943999996045
# Stats from collect loop:  {'return': 90.46580477552794, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3861389000003328
# Iter 66 | replay=4390 | last_loss=0.08755260705947876
# main loop iter: 67
# time: 546.8297062000006
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6106454000000667
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5206719999996494
# Stats from collect loop:  {'return': 90.65669133979137, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.384951899999578
# Iter 67 | replay=4418 | last_loss=0.08740834146738052
# main loop iter: 68
# time: 550.3462528000005
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.1341597000000547
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.8442324999996345
# Stats from collect loop:  {'return': 84.74262559160546, 'length': 34, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.38137730000016745
# Iter 68 | replay=4452 | last_loss=0.1044827327132225
# main loop iter: 69
# time: 554.7063190000003
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.7768624999998792
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6868894999997792
# Stats from collect loop:  {'return': 87.69746480669545, 'length': 31, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.39979050000056304
# Iter 69 | replay=4483 | last_loss=0.08246023952960968
# main loop iter: 70
# time: 558.5701398000006
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8266926999995121
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5773667000003115
# Stats from collect loop:  {'return': 89.2759708607391, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3901653000002625
# Iter 70 | replay=4512 | last_loss=0.08952952921390533
# main loop iter: 71
# time: 562.3646546000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.640383799999654
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.709147600000506
# Stats from collect loop:  {'return': 89.70816181399324, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.37465049999991606
# Iter 71 | replay=4541 | last_loss=0.0887412577867508
# main loop iter: 72
# time: 566.0891031000006
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6802041999999346
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5876963000000615
# Stats from collect loop:  {'return': 90.00413672143368, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4046707999996215
# Iter 72 | replay=4570 | last_loss=0.10850058495998383
# main loop iter: 73
# time: 569.7619593000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.5576365999995687
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6906360000002678
# Stats from collect loop:  {'return': 91.40657706604387, 'length': 27, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4169155999998111
# Iter 73 | replay=4597 | last_loss=0.08506780862808228
# main loop iter: 74
# time: 573.4274264999999
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6222961000003124
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.523608299999978
# Stats from collect loop:  {'return': 90.51323039760244, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.40660310000021127
# Iter 74 | replay=4625 | last_loss=0.09122971445322037
# main loop iter: 75
# time: 576.9801831999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6983781000008094
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.4325401999994938
# Stats from collect loop:  {'return': 92.2380627417466, 'length': 26, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3986142000003383
# Iter 75 | replay=4651 | last_loss=0.10484054684638977
# main loop iter: 76
# time: 580.5098417000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.622645499999635
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.4828151000001526
# Stats from collect loop:  {'return': 91.81104957069792, 'length': 27, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.41442780000033963
# Iter 76 | replay=4678 | last_loss=0.09445792436599731
# main loop iter: 77
# time: 584.0299577000001
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.784002700000201
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5315018000001146
# Stats from collect loop:  {'return': 90.57656762667882, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.43509350000022096
# Iter 77 | replay=4706 | last_loss=0.096681609749794
# main loop iter: 78
# time: 587.7808037999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.5801209999999628
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.469210700000076
# Stats from collect loop:  {'return': 91.38693703262025, 'length': 27, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4121681000005992
# Iter 78 | replay=4733 | last_loss=0.08782655000686646
# main loop iter: 79
# time: 591.2426013999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.885493800000404
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5876753000002282
# Stats from collect loop:  {'return': 89.59453218355779, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.41261519999989105
# Iter 79 | replay=4762 | last_loss=0.08371494710445404
# main loop iter: 80
# time: 595.1286455000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6436839999996664
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5584997000005387
# Stats from collect loop:  {'return': 90.78981040523274, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.436478999999963
# Iter 80 | replay=4790 | last_loss=0.10799503326416016
# main loop iter: 81
# time: 598.767617
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8495238000004974
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5658591000001252
# Stats from collect loop:  {'return': 89.65932909713455, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.40326589999949647
# Iter 81 | replay=4819 | last_loss=0.09126655757427216
# main loop iter: 82
# time: 602.5865800000006
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.617418899999393
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6997104000001855
# Stats from collect loop:  {'return': 90.44281439102545, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.42030849999991915
# Iter 82 | replay=4847 | last_loss=0.11070826649665833
# main loop iter: 83
# time: 606.3243329000002
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6420620999997482
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5513918000006015
# Stats from collect loop:  {'return': 90.23449524627334, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.40073599999959697
# ...
#   5.26135827]
# DEBUG time: 1.847956599999634
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.737702200000058
# Stats from collect loop:  {'return': 88.04579828350117, 'length': 31, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.37309950000053504
# Iter 272 | replay=11123 | last_loss=0.12805673480033875
# main loop iter: 273
# time: 1419.1245838999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8632863000002544
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.61451709999983
# Stats from collect loop:  {'return': 89.95772198883245, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.38985870000033174
# Iter 273 | replay=11152 | last_loss=0.13235434889793396
# main loop iter: 274
# time: 1422.9924855000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.9127759000002698
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.7981487999995807
# Stats from collect loop:  {'return': 84.9625835617326, 'length': 34, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.39366679999966436
# Iter 274 | replay=11186 | last_loss=0.1417338252067566
# main loop iter: 275
# time: 1427.0973396000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8647154000000228
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.610148400000071
# Stats from collect loop:  {'return': 89.65873231610541, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.41299029999936465
# Iter 275 | replay=11215 | last_loss=0.1311793029308319
# main loop iter: 276
# time: 1430.9854207000003
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8276708000003055
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.9226521999999022
# Stats from collect loop:  {'return': 87.37555361963055, 'length': 31, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.38118849999955273
# Iter 276 | replay=11246 | last_loss=0.10984336584806442
# main loop iter: 277
# time: 1435.1171634000007
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6815955999991274
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.599326700000347
# Stats from collect loop:  {'return': 89.32240179597783, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.42045650000000023
# Iter 277 | replay=11275 | last_loss=0.12668295204639435
# main loop iter: 278
# time: 1438.8187887
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.9422215000004144
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6619258999999147
# Stats from collect loop:  {'return': 89.00008054772438, 'length': 30, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.42787959999986924
# Iter 278 | replay=11305 | last_loss=0.10738895833492279
# main loop iter: 279
# time: 1442.8510910999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.7057182000007742
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.7194029999991471
# Stats from collect loop:  {'return': 89.45013868425818, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.5252934000000096
# Iter 279 | replay=11334 | last_loss=0.105499267578125
# main loop iter: 280
# time: 1446.8018107000003
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.9277202000002944
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5186419999999998
# Stats from collect loop:  {'return': 90.51368229931018, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.37822069999947416
# Iter 280 | replay=11362 | last_loss=0.13822339475154877
# main loop iter: 281
# time: 1450.6266832000006
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.615671999999904
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6968895999998495
# Stats from collect loop:  {'return': 91.02117345548552, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3811206000000311
# Iter 281 | replay=11390 | last_loss=0.12296552956104279
# main loop iter: 282
# time: 1454.3205973999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.5398198000002594
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.4511614000002737
# Stats from collect loop:  {'return': 91.70030153656833, 'length': 27, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3825442999996085
# Iter 282 | replay=11417 | last_loss=0.12809252738952637
# main loop iter: 283
# time: 1457.6943919999999
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6450658000003386
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.7324006999997437
# Stats from collect loop:  {'return': 90.89274363415383, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.37865099999999074
# Iter 283 | replay=11445 | last_loss=0.11833338439464569
# main loop iter: 284
# time: 1461.4507949000003
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6802403000001505
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5882404999993014
# Stats from collect loop:  {'return': 89.27616436418253, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3923958000004859
# Iter 284 | replay=11474 | last_loss=0.11070623993873596
# main loop iter: 285
# time: 1465.1119786000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.1760116999994352
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.8825364000003901
# Stats from collect loop:  {'return': 83.58159472223612, 'length': 35, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3795866999998907
# Iter 285 | replay=11509 | last_loss=0.13120552897453308
# main loop iter: 286
# time: 1469.5503715999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.7862054000006538
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.85507460000008
# Stats from collect loop:  {'return': 88.0535988809053, 'length': 31, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.39794159999928524
# Iter 286 | replay=11540 | last_loss=0.13330009579658508
# main loop iter: 287
# time: 1473.5898281000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8020943999999872
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.731906799999706
# Stats from collect loop:  {'return': 87.26007177320082, 'length': 31, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.3954286999996839
# Iter 287 | replay=11571 | last_loss=0.10562261193990707
# main loop iter: 288
# time: 1477.5195482000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.8639505000001009
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5582668999995803
# Stats from collect loop:  {'return': 89.5471092494901, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.40024350000021514
# Iter 288 | replay=11600 | last_loss=0.10282692313194275
# main loop iter: 289
# time: 1481.3422882
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.5490347000004476
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5030700999996043
# Stats from collect loop:  {'return': 91.49765784501199, 'length': 27, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4238727000001745
# Iter 289 | replay=11627 | last_loss=0.1244974136352539
# main loop iter: 290
# time: 1484.8185758000004
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.826147900000251
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5723706999997376
# Stats from collect loop:  {'return': 90.35929608393687, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4173204999997324
# Iter 290 | replay=11655 | last_loss=0.13174225389957428
# main loop iter: 291
# time: 1488.6346469000005
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.819170299999314
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5544315000006463
# Stats from collect loop:  {'return': 91.71055596421219, 'length': 27, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4197091999994882
# Iter 291 | replay=11682 | last_loss=0.11065593361854553
# main loop iter: 292
# time: 1492.4281858999998
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.9666809000000285
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.668419399999948
# Stats from collect loop:  {'return': 89.6339012595476, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4283364000002621
# Iter 292 | replay=11711 | last_loss=0.16073107719421387
# main loop iter: 293
# time: 1496.4917404000003
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.6866289999998116
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.5731061000005866
# Stats from collect loop:  {'return': 90.66229887887413, 'length': 28, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4411304999994172
# Iter 293 | replay=11739 | last_loss=0.12942858040332794
# main loop iter: 294
# time: 1500.1929045000002
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.9260928000003332
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.621348699999544
# Stats from collect loop:  {'return': 90.08145311914825, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.45234200000049896
# Iter 294 | replay=11768 | last_loss=0.1440230756998062
# main loop iter: 295
# time: 1504.1928161
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.7662090000003445
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.833139299999857
# Stats from collect loop:  {'return': 89.12797452276381, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.43877100000008795
# Iter 295 | replay=11797 | last_loss=0.1340416967868805
# main loop iter: 296
# time: 1508.2312592000003
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.9091779000000315
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.8038012999995772
# Stats from collect loop:  {'return': 87.0138383775477, 'length': 32, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.42488760000014736
# Iter 296 | replay=11829 | last_loss=0.10930553078651428
# main loop iter: 297
# time: 1512.3694405
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.988137800000004
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6861919000002672
# Stats from collect loop:  {'return': 88.53744776217565, 'length': 30, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.41893439999967086
# Iter 297 | replay=11859 | last_loss=0.1141909807920456
# main loop iter: 298
# time: 1516.4630086000002
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 1.721047400000316
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6241548999996667
# Stats from collect loop:  {'return': 90.09794080847341, 'length': 29, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.4251396999998178
# Iter 298 | replay=11888 | last_loss=0.14806316792964935
# main loop iter: 299
# time: 1520.2336813000006
# DEBUG: EVAL DEBUG EPISODE RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# DEBUG time: 2.0133662999996886
# DEBUG: COLLECTION RUN WITH OBS: [ 1.66346224 -8.16389257 -7.82907133  8.07993967 -3.96681008  1.47075328
#   5.26135827]
# collect loop time: 1.6797937999999704
# Stats from collect loop:  {'return': 88.74437197637162, 'length': 30, 'done': True, 'terminated': True, 'truncated': False}
# train loop time: 0.49497880000035366
# Iter 299 | replay=11918 | last_loss=0.1436922699213028

# %%
stats
# Out:
# {'return': 88.74437197637162,
#  'length': 30,
#  'done': True,
#  'terminated': True,
#  'truncated': False}

# %%
len(replay)
# Out:
# 11918

# %%
cfg.batch_size
# Out:
# 128

# %% [markdown]
# # Debug Plots

# %% [markdown]
# ## load debug pickle data

# %%
import gc
import matplotlib.pyplot as plt

plt.close("all")   # release figure refs
try:
    del dbg
except NameError:
    pass
gc.collect()

from IPython.display import clear_output
clear_output(wait=True)

with open("debug_traces/trace_ep000149_seed1009.pkl", "rb") as f:
    dbg = pickle.load(f)

# %%
dbg.keys()
# Out:
# dict_keys(['seed', 'info', 'states', 'roots', 'chosen_idx', 'actions', 'network_outputs', 'targets_from_root', 'train_episode'])

# %%
from graphviz import Digraph

def mcts_to_graphviz(root, *, depth_limit=None, max_nodes=2000, highlight_child_idx=None):
    """
    Build a Graphviz Digraph for an MCTS tree rooted at `root`.

    depth_limit: None for full depth, or int to cap depth
    max_nodes: stop after this many nodes (safety)
    highlight_child_idx: if given, highlight that root child edge/node
    """
    dot = Digraph(comment="MCTS Tree")
    dot.attr("node", shape="box", fontsize="10")
    dot.attr("edge", fontsize="9")

    # Assign stable ids
    node_id = {}
    next_id = 0

    def get_id(node):
        nonlocal next_id
        k = id(node)
        if k not in node_id:
            node_id[k] = f"n{next_id}"
            next_id += 1
        return node_id[k]

    # BFS/DFS traversal
    stack = [(root, 0)]
    seen = set()
    created = 0

    while stack:
        node, depth = stack.pop()
        nid = get_id(node)

        if nid in seen:
            continue
        seen.add(nid)

        # Stop conditions
        if created >= max_nodes:
            break
        if depth_limit is not None and depth > depth_limit:
            continue

        # Node label
        N = getattr(node, "N", 0)
        v = getattr(node, "v", None)
        is_term = getattr(node, "is_terminal", False)
        term_v = getattr(node, "terminal_value", None)

        label = f"N={N}"
        if v is not None:
            label += f"\\nv={float(v):.3f}"
        if is_term:
            label += "\\nTERMINAL"
            if term_v is not None:
                label += f"\\nTv={float(term_v):.3f}"

        # Style terminal nodes
        if is_term:
            dot.node(nid, label=label, style="filled", fillcolor="lightgray")
        else:
            dot.node(nid, label=label)

        created += 1

        # Children edges
        children = getattr(node, "children", [])
        for i, ch in enumerate(children):
            child = ch.child_node
            cid = get_id(child)

            # Edge label includes stats
            a = np.array(ch.action).tolist()
            edge_label = (
                f"a={a}"
                f"\\nr={float(ch.r_sa):.3f}"
                f"\\nN={int(ch.N_sa)}"
                f"\\nQ={float(ch.Q_sa):.3f}"
                f"\\nP={float(ch.P_sa):.3g}"
            )

            # Highlight chosen root child
            if node is root and highlight_child_idx is not None and i == int(highlight_child_idx):
                dot.edge(nid, cid, label=edge_label, penwidth="3")
                dot.node(cid, style="filled", fillcolor="palegreen")
            else:
                dot.edge(nid, cid, label=edge_label)

            # Continue traversal
            stack.append((child, depth + 1))

    if created >= max_nodes:
        # Add a note node
        dot.node("TRUNC", f"TRUNCATED at max_nodes={max_nodes}", style="filled", fillcolor="orange")
    return dot

# %%
from ipywidgets import interact, IntSlider

def inspect_debug_trace(dbg, *, depth_limit=3, max_nodes=2000):
    states = dbg["states"]
    roots = dbg["roots"]
    chosen = dbg["chosen_idx"]
    info = dbg["info"]
    record_every = max(1, int(dbg.get("record_every", 1)))  # optional if you store it

    def view(k):
        # k indexes into recorded roots
        env_t = k * record_every

        # state plot
        plot_seeker_obs(states[env_t], info, title=f"Seed={dbg['seed']} | train_ep={dbg.get('train_episode')} | t={env_t}")

        # tree plot
        dot = mcts_to_graphviz(
            roots[k],
            depth_limit=depth_limit,
            max_nodes=max_nodes,
            highlight_child_idx=chosen[k],
        )
        return dot

    interact(view, k=IntSlider(min=0, max=len(roots)-1, step=1, value=0))

# %%
inspect_debug_trace(dbg, depth_limit=10, max_nodes=2000)
# Out:
# interactive(children=(IntSlider(value=0, description='k', max=36), Output(outputs=({'output_type': 'display_da…

# %%
def collect_tree_edges(root, depth_limit=None, max_nodes=5000):
    """
    Traverse the tree and collect (parent_node, child_node, child_edge, depth_child).
    """
    edges = []
    stack = [(root, 0)]
    seen = set()
    node_count = 0

    while stack:
        node, depth = stack.pop()
        node_id = id(node)
        if node_id in seen:
            continue
        seen.add(node_id)
        node_count += 1
        if node_count > max_nodes:
            break

        if depth_limit is not None and depth >= depth_limit:
            continue

        for ch in getattr(node, "children", []):
            child = ch.child_node
            edges.append((node, child, ch, depth + 1))
            stack.append((child, depth + 1))

    return edges


def plot_mcts_tree_xy(
    root,
    info,
    chosen_child_idx=None,
    depth_limit=6,
    max_nodes=4000,
    show_edge_text=False,
    highlight_subtree=False,
    title=None,
):
    """
    Visualize an MCTS tree in environment XY coordinates.
    - chosen_child_idx highlights the root->child edge that planner.act picked.
    - highlight_subtree: if True, highlight the entire subtree under chosen child.
    """
    root_obs = root.state
    agent0, goal, obstacles = decode_obs(root_obs)
    L = info.get("boundary_size", 10)

    edges = collect_tree_edges(root, depth_limit=depth_limit, max_nodes=max_nodes)

    # Precompute positions
    def pos(node):
        a, _, _ = decode_obs(node.state)
        return float(a[0]), float(a[1])

    # Determine which nodes/edges are in the chosen subtree (optional)
    chosen_subtree_nodes = set()
    chosen_child_node = None
    if chosen_child_idx is not None and 0 <= chosen_child_idx < len(root.children):
        chosen_child_node = root.children[int(chosen_child_idx)].child_node

    if highlight_subtree and chosen_child_node is not None:
        stack = [chosen_child_node]
        while stack:
            n = stack.pop()
            if id(n) in chosen_subtree_nodes:
                continue
            chosen_subtree_nodes.add(id(n))
            for ch in getattr(n, "children", []):
                stack.append(ch.child_node)

    fig, ax = plt.subplots(figsize=(7, 7))

    # Obstacles
    for (ox, oy, r) in obstacles:
        ax.add_patch(plt.Circle((ox, oy), r, alpha=0.3))
    # Goal / Agent
    ax.scatter(goal[0], goal[1], s=140, marker="*", label="Goal", zorder=5)
    ax.scatter(agent0[0], agent0[1], s=90, label="Root state", zorder=6)

    # Draw edges + nodes
    # Draw non-highlight edges first
    for parent, child, ch, d in edges:
        x0, y0 = pos(parent)
        x1, y1 = pos(child)

        is_chosen_edge = (parent is root and chosen_child_node is child)
        in_chosen_subtree = (highlight_subtree and id(child) in chosen_subtree_nodes)

        # Edge style
        if is_chosen_edge:
            lw = 3.0
            alpha = 0.9
        elif in_chosen_subtree:
            lw = 2.0
            alpha = 0.6
        else:
            lw = 1.0
            alpha = 0.25

        ax.plot([x0, x1], [y0, y1], linewidth=lw, alpha=alpha, zorder=1)

        if show_edge_text:
            mx, my = (x0 + x1) / 2, (y0 + y1) / 2
            ax.text(
                mx, my,
                f"N={ch.N_sa}\nQ={ch.Q_sa:.2f}\nP={ch.P_sa:.2g}",
                fontsize=7,
                alpha=0.8,
                ha="center", va="center"
            )

    # Scatter nodes (child endpoints)
    xs, ys, sizes, alphas = [], [], [], []
    xs_hi, ys_hi = [], []
    for parent, child, ch, d in edges:
        x1, y1 = pos(child)
        xs.append(x1); ys.append(y1)
        sizes.append(18 + 6 * min(d, 6))
        alphas.append(0.15 + 0.10 * (depth_limit - d) if depth_limit else 0.2)

        if chosen_child_node is child:
            xs_hi.append(x1); ys_hi.append(y1)

    ax.scatter(xs, ys, s=sizes, alpha=0.35, label="Tree nodes", zorder=3)
    if xs_hi:
        ax.scatter(xs_hi, ys_hi, s=140, alpha=0.95, label="Chosen child", zorder=7)

    ax.set_xlim(-L, L)
    ax.set_ylim(-L, L)
    ax.set_aspect("equal", adjustable="box")
    ax.legend(loc="upper right")

    if title:
        ax.set_title(title)

    # Print root-child stats as a small table-like text
    if len(getattr(root, "children", [])) > 0:
        lines = ["Root children (sorted by N):"]
        rows = []
        for i, ch in enumerate(root.children):
            rows.append((i, ch.N_sa, ch.Q_sa, ch.P_sa, ch.r_sa, np.array(ch.action)))
        rows.sort(key=lambda r: r[1], reverse=True)

        for (i, N, Q, P, r, a) in rows[:12]:  # top 12
            star = " <= chosen" if (chosen_child_idx is not None and i == int(chosen_child_idx)) else ""
            lines.append(f"[{i}] N={N:4d}  Q={Q:7.3f}  P={P:8.3g}  r={r:7.3f}  a={a}{star}")

        # place text under plot
        fig.text(0.02, 0.02, "\n".join(lines), fontsize=9, va="bottom")

    plt.show()
    return fig

# %%
from ipywidgets import interact, IntSlider

def inspect_debug_trace_xy(dbg, *, depth_limit=6, max_nodes=4000, show_edge_text=False, highlight_subtree=False):
    roots = dbg["roots"]
    chosen = dbg["chosen_idx"]
    info = dbg["info"]
    record_every = max(1, int(dbg.get("record_every", 1)))

    def view(k):
        env_t = k * record_every
        plot_mcts_tree_xy(
            roots[k],
            info,
            chosen_child_idx=chosen[k] if k < len(chosen) else None,
            depth_limit=depth_limit,
            max_nodes=max_nodes,
            show_edge_text=show_edge_text,
            highlight_subtree=highlight_subtree,
            title=f"Seed={dbg['seed']} | train_ep={dbg.get('train_episode')} | t={env_t}"
        )

    interact(view, k=IntSlider(min=0, max=len(roots)-1, step=1, value=0))

# %%
#dbg = run_debug_eval_episode(env_eval=env_eval, planner=planner, seed=0, max_steps=200, record_every=1)
#dbg["record_every"] = 1
#dbg["train_episode"] = 500

inspect_debug_trace_xy(dbg, depth_limit=3, max_nodes=4000, highlight_subtree=True)
# Out:
# interactive(children=(IntSlider(value=0, description='k', max=36), Output()), _dom_classes=('widget-interact',…

# %% [markdown]
# ## Plot for seeker trajectory

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_seeker_trajectory(states, title=None, cmap="viridis",
                           show_line=True, show_points=True, annotate=False):
    """
    states: list/iterable of obs vectors (each encodes agent, goal, obstacles)
    info: dict with boundary_size etc.
    """
    if len(states) == 0:
        return

    # Use first state for static elements (goal/obstacles/boundary)
    agent0, goal, obstacles = decode_obs(states[0])
    L = 10

    # Extract agent positions over time
    agents = np.array([decode_obs(s)[0] for s in states])  # shape (T, 2)
    T = len(agents)
    t = np.arange(T)

    fig, ax = plt.subplots(figsize=(6, 6))

    # Obstacles
    for (ox, oy, r) in obstacles:
        ax.add_patch(plt.Circle((ox, oy), r, color="red", alpha=0.3))

    # Goal
    ax.scatter(goal[0], goal[1], color="green", s=120, marker="*", label="Goal", zorder=3)

    # Trajectory
    if show_line:
        ax.plot(agents[:, 0], agents[:, 1], linewidth=2, alpha=0.7, label="Path", zorder=2)

    if show_points:
        sc = ax.scatter(
            agents[:, 0], agents[:, 1],
            c=t, cmap=cmap, s=35, zorder=4
        )
        plt.colorbar(sc, ax=ax, fraction=0.046, pad=0.04, label="Step")

    # Start / End markers
    ax.scatter(agents[0, 0], agents[0, 1], color="cyan", s=90, label="Start", zorder=5)
    ax.scatter(agents[-1, 0], agents[-1, 1], color="black", s=90, label="End", zorder=5)

    if annotate:
        for i, (x, y) in enumerate(agents):
            ax.text(x, y, str(i), fontsize=8)

    ax.set_xlim(-L, L)
    ax.set_ylim(-L, L)
    ax.set_aspect("equal", adjustable="box")
    ax.legend(loc="upper right")
    if title:
        ax.set_title(title)
    plt.show()

# %% [markdown]
# ### Trajectory from debug eval

# %%
plot_seeker_trajectory(dbg["states"], title=f"Seed {dbg['seed']} ep {dbg.get('train_episode')}")

# %% [markdown]
# ### Trajectory from data collection

# %%
states_collect = [np.asarray(r.state).copy() for r in roots_collect]
plot_seeker_trajectory(states_collect, title=f"Seed {dbg['seed']} ep {dbg.get('train_episode')}")

# %% [markdown]
# #### At this point I know, that debug and train collection are the same.

# %% [markdown]
# ## More comparisons between train and debug just for sanity

# %% [markdown]
# ## Plot for MCTS tree

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_mcts_tree_xy(
    root,
    obs,
    *,
    L=10,
    title=None,
    ax=None,
    chosen_child_idx=None,
):
    """Full tree in XY, with optional highlight of the chosen root child."""
    agent, goal, obstacles = decode_obs(obs)

    def node_xy(node):
        a, _, _ = decode_obs(np.asarray(node.state))
        return float(a[0]), float(a[1])

    # identify chosen child node (optional)
    chosen_child_node = None
    if chosen_child_idx is not None and 0 <= int(chosen_child_idx) < len(getattr(root, "children", [])):
        chosen_child_node = root.children[int(chosen_child_idx)].child_node

    # traverse tree
    edges = []  # (parent, child, is_chosen_root_edge)
    stack = [root]
    seen = set()

    while stack:
        node = stack.pop()
        nid = id(node)
        if nid in seen:
            continue
        seen.add(nid)

        for ch in getattr(node, "children", []):
            child = ch.child_node
            is_chosen = (node is root and chosen_child_node is child)
            edges.append((node, child, is_chosen))
            stack.append(child)

    if ax is None:
        _, ax = plt.subplots(figsize=(6, 6))

    # obstacles
    for (ox, oy, r) in obstacles:
        ax.add_patch(plt.Circle((ox, oy), r, alpha=0.3))

    # goal and agent
    ax.scatter(goal[0], goal[1], s=120, marker="*", label="Goal", zorder=5)
    ax.scatter(agent[0], agent[1], s=90, label="Agent (obs)", zorder=6)

    # edges
    for parent, child, is_chosen in edges:
        x0, y0 = node_xy(parent)
        x1, y1 = node_xy(child)
        if is_chosen:
            ax.plot([x0, x1], [y0, y1], linewidth=3, alpha=0.9, label="Chosen edge", zorder=2)
        else:
            ax.plot([x0, x1], [y0, y1], linewidth=1, alpha=0.35, zorder=1)

    # nodes
    xs, ys = [], []
    for _, child, _ in edges:
        x, y = node_xy(child)
        xs.append(x); ys.append(y)

    xr, yr = node_xy(root)
    ax.scatter([xr], [yr], s=80, marker="s", label="MCTS root", zorder=7)
    if xs:
        ax.scatter(xs, ys, s=20, alpha=0.5, label="Tree nodes", zorder=3)

    # highlight chosen child node
    if chosen_child_node is not None:
        xc, yc = node_xy(chosen_child_node)
        ax.scatter([xc], [yc], s=110, alpha=0.9, label="Chosen child", zorder=8)

    ax.set_xlim(-L, L)
    ax.set_ylim(-L, L)
    ax.set_aspect("equal", adjustable="box")
    if title:
        ax.set_title(title)
    return ax


def plot_mcts_tree_xy_limited(
    root,
    obs,
    *,
    L=10,
    title=None,
    ax=None,
    max_depth=6,
    top_k_per_node=5,
    chosen_child_idx=None,
):
    """Tree in XY, limited by depth and top-K children per node, with chosen root child highlight."""
    agent, goal, obstacles = decode_obs(obs)

    def node_xy(node):
        a, _, _ = decode_obs(np.asarray(node.state))
        return float(a[0]), float(a[1])

    chosen_child_node = None
    if chosen_child_idx is not None and 0 <= int(chosen_child_idx) < len(getattr(root, "children", [])):
        chosen_child_node = root.children[int(chosen_child_idx)].child_node

    edges = []  # (parent, child, is_chosen_root_edge)
    stack = [(root, 0)]
    seen = set()

    while stack:
        node, depth = stack.pop()
        nid = id(node)
        if nid in seen:
            continue
        seen.add(nid)

        if depth >= int(max_depth):
            continue

        children = list(getattr(node, "children", []))
        children.sort(key=lambda ch: ch.N_sa, reverse=True)
        children = children[: int(top_k_per_node)]

        for ch in children:
            child = ch.child_node
            is_chosen = (node is root and chosen_child_node is child)
            edges.append((node, child, is_chosen))
            stack.append((child, depth + 1))

    if ax is None:
        _, ax = plt.subplots(figsize=(6, 6))

    for (ox, oy, r) in obstacles:
        ax.add_patch(plt.Circle((ox, oy), r, alpha=0.3))

    ax.scatter(goal[0], goal[1], s=120, marker="*", label="Goal", zorder=5)
    ax.scatter(agent[0], agent[1], s=90, label="Agent (obs)", zorder=6)

    for parent, child, is_chosen in edges:
        x0, y0 = node_xy(parent)
        x1, y1 = node_xy(child)
        if is_chosen:
            ax.plot([x0, x1], [y0, y1], linewidth=3, alpha=0.9, label="Chosen edge", zorder=2)
        else:
            ax.plot([x0, x1], [y0, y1], linewidth=1, alpha=0.35, zorder=1)

    xs, ys = [], []
    for _, child, _ in edges:
        x, y = node_xy(child)
        xs.append(x); ys.append(y)

    xr, yr = node_xy(root)
    ax.scatter([xr], [yr], s=80, marker="s", label="MCTS root", zorder=7)
    if xs:
        ax.scatter(xs, ys, s=20, alpha=0.5, label="Tree nodes", zorder=3)

    if chosen_child_node is not None:
        xc, yc = node_xy(chosen_child_node)
        ax.scatter([xc], [yc], s=110, alpha=0.9, label="Chosen child", zorder=8)

    ax.set_xlim(-L, L)
    ax.set_ylim(-L, L)
    ax.set_aspect("equal", adjustable="box")
    if title:
        ax.set_title(title)
    return ax

# %%
print("Have same length: ", bool(len(dbg["roots"]) == len(roots_collect)))

n = min(len(dbg["roots"]), len(roots_collect))
n = 2

for i in range(n):
    fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharex=True, sharey=True)

    idx = int(np.argmin([np.max(np.abs(ch.action - action)) for ch in dbg["roots"][i].children]))
    plot_mcts_tree_xy(dbg["roots"][i], DEBUG_OBS, ax=axes[0], title=f"Debug i={i}", chosen_child_idx=idx)

    idx = int(np.argmin([np.max(np.abs(ch.action - action)) for ch in roots_collect[i].children]))
    plot_mcts_tree_xy(roots_collect[i], DEBUG_OBS, ax=axes[1], title=f"Collect i={i}", chosen_child_idx=idx)

    # show legend only once (optional)
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(handles, labels, loc="upper right")

    plt.tight_layout()
    plt.show()
# Out:
# Have same length:  False

# %%
print("Have same length: ", bool(len(dbg["roots"]) == len(roots_collect)))

n = min(len(dbg["roots"]), len(roots_collect))
n = 2

for i in range(n):
    fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharex=True, sharey=True)

    idx = int(np.argmin([np.max(np.abs(ch.action - action)) for ch in dbg["roots"][i].children]))
    plot_mcts_tree_xy_limited(dbg["roots"][i], DEBUG_OBS, ax=axes[0], title=f"Debug i={i}", max_depth=4, top_k_per_node=4, chosen_child_idx=idx)

    idx = int(np.argmin([np.max(np.abs(ch.action - action)) for ch in roots_collect[i].children]))
    plot_mcts_tree_xy_limited(roots_collect[i], DEBUG_OBS, ax=axes[1], title=f"Collect i={i}", max_depth=4, top_k_per_node=4, chosen_child_idx=idx)

    # show legend only once (optional)
    handles, labels = axes[0].get_legend_handles_labels()
    fig.legend(handles, labels, loc="upper right")

    plt.tight_layout()
    plt.show()
# Out:
# Have same length:  False

# %% [markdown]
# ## Plots for debugging the real issue (bad Q values)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

def plot_dbg_step(
    dbg,
    k: int,
    *,
    L=10,
    max_depth=6,
    top_k_per_node=5,
    title=None,
    ax=None,
    nsig=1.0,  # ellipse radius in "number of std devs"
):
    roots = dbg["roots"]
    states = dbg["states"]
    chosen_idx = dbg["chosen_idx"]
    net_out = dbg["network_outputs"]
    tgt_out = dbg["targets_from_root"]

    if k < 0 or k >= len(roots):
        raise IndexError(f"k={k} out of range, have {len(roots)} roots")

    root = roots[k]
    obs_k = states[k]
    agent, goal, obstacles = decode_obs(obs_k)

    if ax is None:
        _, ax = plt.subplots(figsize=(6, 6))

    # --- environment ---
    for (ox, oy, r) in obstacles:
        ax.add_patch(plt.Circle((ox, oy), r, alpha=0.3))
    ax.scatter(goal[0], goal[1], s=120, marker="*", label="Goal", zorder=6)

    # --- past trajectory (0..k) ---
    agents = np.array([decode_obs(s)[0] for s in states[: k + 1]])
    t = np.arange(len(agents))
    ax.plot(agents[:, 0], agents[:, 1], linewidth=2, alpha=0.5, zorder=2)
    sc = ax.scatter(agents[:, 0], agents[:, 1], c=t, cmap="viridis", s=25, zorder=3)
    plt.colorbar(sc, ax=ax, fraction=0.046, pad=0.04, label="t")

    ax.scatter(agents[0, 0], agents[0, 1], s=80, label="Start", zorder=7)
    ax.scatter(agent[0], agent[1], s=90, label=f"Agent @ t={k}", zorder=8)

    # --- helpers for tree ---
    def node_xy(node):
        a, _, _ = decode_obs(np.asarray(node.state))
        return float(a[0]), float(a[1])

    # chosen child node
    chosen_child_node = None
    cidx = int(chosen_idx[k]) if k < len(chosen_idx) else None
    if cidx is not None and 0 <= cidx < len(getattr(root, "children", [])):
        chosen_child_node = root.children[cidx].child_node

    # traverse limited tree
    edges = []
    stack = [(root, 0)]
    seen = set()

    while stack:
        node, depth = stack.pop()
        nid = id(node)
        if nid in seen:
            continue
        seen.add(nid)

        if depth >= int(max_depth):
            continue

        children = list(getattr(node, "children", []))
        children.sort(key=lambda ch: ch.N_sa, reverse=True)
        children = children[: int(top_k_per_node)]

        for ch in children:
            child = ch.child_node
            is_chosen = (node is root and chosen_child_node is child)
            edges.append((node, child, is_chosen))
            stack.append((child, depth + 1))

    for parent, child, is_chosen in edges:
        x0, y0 = node_xy(parent)
        x1, y1 = node_xy(child)
        if is_chosen:
            ax.plot([x0, x1], [y0, y1], linewidth=3, alpha=0.9, zorder=5)
        else:
            ax.plot([x0, x1], [y0, y1], linewidth=1, alpha=0.25, zorder=4)

    xs, ys = [], []
    for _, child, _ in edges:
        x, y = node_xy(child)
        xs.append(x); ys.append(y)

    xr, yr = node_xy(root)
    ax.scatter([xr], [yr], s=70, marker="s", label="MCTS root", zorder=9)
    if xs:
        ax.scatter(xs, ys, s=18, alpha=0.35, zorder=6)

    if chosen_child_node is not None:
        xc, yc = node_xy(chosen_child_node)
        ax.scatter([xc], [yc], s=120, alpha=0.9, label="Chosen child", zorder=10)

    # --- Gaussian ellipses (assumes action is delta-x, delta-y) ---
    mu, log_std, v = net_out[k]
    mu = np.asarray(mu).reshape(-1)
    std = np.exp(np.asarray(log_std).reshape(-1))

    mu_s, log_std_s, v_s = tgt_out[k]
    mu_s = np.asarray(mu_s).reshape(-1)
    std_s = np.exp(np.asarray(log_std_s).reshape(-1))

    c_net = np.array([agent[0], agent[1]]) + mu[:2]
    c_tgt = np.array([agent[0], agent[1]]) + mu_s[:2]

    # arrows (colored)
    ax.arrow(agent[0], agent[1], c_net[0]-agent[0], c_net[1]-agent[1],
             length_includes_head=True, head_width=0.15, alpha=0.8,
             color="steelblue", zorder=11)
    ax.arrow(agent[0], agent[1], c_tgt[0]-agent[0], c_tgt[1]-agent[1],
             length_includes_head=True, head_width=0.15, alpha=0.8,
             color="orange", zorder=11)

    w_net = 2.0 * nsig * float(std[0]);  h_net = 2.0 * nsig * float(std[1])
    w_tgt = 2.0 * nsig * float(std_s[0]); h_tgt = 2.0 * nsig * float(std_s[1])

    # ellipses (colored, not dashed)
    ax.add_patch(Ellipse((c_net[0], c_net[1]), w_net, h_net,
                         angle=0.0, fill=False, linewidth=2,
                         edgecolor="steelblue", alpha=0.9, label="Net (μ,σ)"))
    ax.add_patch(Ellipse((c_tgt[0], c_tgt[1]), w_tgt, h_tgt,
                         angle=0.0, fill=False, linewidth=2,
                         edgecolor="orange", alpha=0.9, label="Target (μ*,σ*)"))

    ax.text(0.02, 0.98, f"v={float(v):.3f}\nv*={float(v_s):.3f}",
            transform=ax.transAxes, va="top", fontsize=10)

    ax.set_xlim(-L, L)
    ax.set_ylim(-L, L)
    ax.set_aspect("equal", adjustable="box")
    ax.set_title(title if title is not None else f"seed={dbg.get('seed')}  t={k}")

    ax.legend(loc="upper right")
    return ax

# %%
n = len(dbg["roots"])

for i in range(n):
    fig, ax = plt.subplots(1, 1, figsize=(12, 6), sharex=True, sharey=True)
    plot_dbg_step(dbg, i, ax=ax, max_depth=99, top_k_per_node=4, title=f"DEBUG t={i}")
    plt.tight_layout()
    plt.show()
    print("network:", dbg["network_outputs"][i])
    print("target:", dbg["targets_from_root"][i])
# Out:
# network: (array([0.00454868, 0.34370908], dtype=float32), array([-0.7219914 , -0.80555415], dtype=float32), -17.209020614624023)
# target: (array([0.10764846, 0.7551214 ], dtype=float32), array([-0.7565693, -0.9786016], dtype=float32), -17.741683512088322)
# network: (array([0.07004143, 0.12721536], dtype=float32), array([-0.68993914, -0.86947536], dtype=float32), -16.514083862304688)
# target: (array([-0.15816882,  0.50390124], dtype=float32), array([-0.9933072, -1.0214415], dtype=float32), -17.262605859794146)
# network: (array([0.20430829, 0.47861192], dtype=float32), array([-1.0382961, -1.1698817], dtype=float32), -16.706398010253906)
# target: (array([0.11327749, 0.77357227], dtype=float32), array([-1.4996283, -1.487081 ], dtype=float32), -15.543736473159765)
# network: (array([0.40994412, 0.7945103 ], dtype=float32), array([-1.4769887, -1.4921956], dtype=float32), -15.613887786865234)
# target: (array([0.6324423 , 0.85590297], dtype=float32), array([-1.4878556, -1.5599008], dtype=float32), -14.33536503215949)
# network: (array([0.44022018, 0.6589938 ], dtype=float32), array([-1.2320696, -1.2346754], dtype=float32), -14.576459884643555)
# target: (array([0.22842386, 0.92600065], dtype=float32), array([-1.6757312, -1.4094352], dtype=float32), -12.226038095372855)
# network: (array([0.5575033 , 0.66792554], dtype=float32), array([-1.155085, -1.235844], dtype=float32), -13.458040237426758)
# target: (array([0.7072594, 0.7415481], dtype=float32), array([-1.2150484, -1.3120066], dtype=float32), -11.947364198764733)
# network: (array([0.46078968, 0.7617252 ], dtype=float32), array([-1.42619 , -1.478911], dtype=float32), -9.249212265014648)
# target: (array([0.38724646, 0.7338469 ], dtype=float32), array([-1.3677292, -1.3547984], dtype=float32), -10.213974948364623)
# network: (array([0.5141863, 0.6859756], dtype=float32), array([-1.5190254, -1.5139118], dtype=float32), -7.270018100738525)
# target: (array([0.6797681 , 0.69888073], dtype=float32), array([-1.26814  , -1.2248126], dtype=float32), -4.567002834740499)
# network: (array([0.57171214, 0.5895223 ], dtype=float32), array([-1.3864167, -1.374722 ], dtype=float32), -8.694364547729492)
# target: (array([0.5566538 , 0.87490475], dtype=float32), array([-1.424189 , -1.2762151], dtype=float32), -1.8689296148247128)
# network: (array([0.2324719 , 0.83886266], dtype=float32), array([-1.51808  , -1.4486302], dtype=float32), -3.7457127571105957)
# target: (array([0.23896044, 0.8426594 ], dtype=float32), array([-1.1683158, -1.3740273], dtype=float32), 0.4751682069730782)
# network: (array([-0.13194202,  0.8663257 ], dtype=float32), array([-1.5482802, -1.4574559], dtype=float32), 1.9907536506652832)
# target: (array([-0.18235339,  0.8914913 ], dtype=float32), array([-1.7470177, -1.2874566], dtype=float32), 2.890982532165256)
# network: (array([-0.2222672,  0.8422228], dtype=float32), array([-1.4891115, -1.4439764], dtype=float32), 3.5491809844970703)
# target: (array([-0.36168593,  0.8676989 ], dtype=float32), array([-2.0316858, -1.2704326], dtype=float32), 6.18149824563825)
# network: (array([-0.26676536,  0.80961293], dtype=float32), array([-1.3588269, -1.407665 ], dtype=float32), 4.414693832397461)
# target: (array([-0.19996065,  0.85075533], dtype=float32), array([-1.712677 , -1.1239704], dtype=float32), 6.800678483829698)
# network: (array([-0.63004565,  0.76421654], dtype=float32), array([-1.3246268, -1.408622 ], dtype=float32), 9.779531478881836)
# target: (array([-0.48410878,  0.866815  ], dtype=float32), array([-1.8767009, -1.3390634], dtype=float32), 14.372137400523245)
# network: (array([-0.7462646,  0.6157493], dtype=float32), array([-1.2343514, -1.4782271], dtype=float32), 12.955392837524414)
# target: (array([-0.8153217 ,  0.62792754], dtype=float32), array([-1.107553 , -1.4617182], dtype=float32), 15.331265042115554)
# network: (array([-0.87152994,  0.37613437], dtype=float32), array([-1.051051 , -1.4625275], dtype=float32), 20.954553604125977)
# target: (array([-0.7010617 ,  0.41284692], dtype=float32), array([-1.1494333, -1.5500418], dtype=float32), 17.963451677410756)
# network: (array([-0.7953998 ,  0.39982632], dtype=float32), array([-1.4817241, -1.6676539], dtype=float32), 24.21184539794922)
# target: (array([-0.51997054,  0.37417316], dtype=float32), array([-0.79187244, -1.5973142 ], dtype=float32), 15.080529978529391)
# network: (array([-0.82533437,  0.50336564], dtype=float32), array([-1.4735367, -1.569231 ], dtype=float32), 20.870912551879883)
# target: (array([0.32135668, 0.0487911 ], dtype=float32), array([-0.3337285, -1.1277704], dtype=float32), 14.17413462043189)
# network: (array([-0.8264975 ,  0.30285764], dtype=float32), array([-1.4165583, -1.6612823], dtype=float32), 26.620214462280273)
# target: (array([-0.52981305,  0.15679477], dtype=float32), array([-1.0345342, -1.3652381], dtype=float32), 14.958824680593322)
# network: (array([-0.8270829,  0.4057657], dtype=float32), array([-1.5206978, -1.6852403], dtype=float32), 26.035009384155273)
# target: (array([-0.06342268, -0.03874722], dtype=float32), array([-0.34520385, -0.6848029 ], dtype=float32), 15.261550566982658)
# network: (array([-0.8423675 ,  0.46025762], dtype=float32), array([-1.1686137, -1.4761273], dtype=float32), 22.27072525024414)
# target: (array([-0.6427639,  0.4938068], dtype=float32), array([-1.278844 , -1.2589556], dtype=float32), 16.394439138254754)
# network: (array([-0.79431134,  0.40901366], dtype=float32), array([-1.4769659, -1.661118 ], dtype=float32), 23.61687469482422)
# target: (array([-0.6864285,  0.4025517], dtype=float32), array([-1.0548222, -1.274781 ], dtype=float32), 14.964587638886005)
# network: (array([-0.8320916 ,  0.45369706], dtype=float32), array([-1.4456418, -1.5789226], dtype=float32), 21.682899475097656)
# target: (array([-0.24709576,  0.1049193 ], dtype=float32), array([-0.41578403, -1.0153118 ], dtype=float32), 19.601595994282356)
# network: (array([-0.83688354,  0.4360606 ], dtype=float32), array([-1.520631 , -1.6667536], dtype=float32), 25.223073959350586)
# target: (array([-0.20231214,  0.14023034], dtype=float32), array([-0.59050506, -0.9289354 ], dtype=float32), 14.060466562370976)
# network: (array([-0.8332235 ,  0.38227156], dtype=float32), array([-1.506762 , -1.6904793], dtype=float32), 26.80327796936035)
# target: (array([-0.07781409,  0.01005617], dtype=float32), array([-0.50459135, -0.9660321 ], dtype=float32), 15.59345356862751)
# network: (array([-0.782797  ,  0.39090014], dtype=float32), array([-1.3157051, -1.6172179], dtype=float32), 24.704675674438477)
# target: (array([-0.53485686,  0.31557098], dtype=float32), array([-1.1416715, -1.5193285], dtype=float32), 16.864616424876257)
# network: (array([-0.83103687,  0.41719833], dtype=float32), array([-1.5221299, -1.6789235], dtype=float32), 25.78019142150879)
# target: (array([-0.63048893,  0.41322052], dtype=float32), array([-1.0099608, -1.3972219], dtype=float32), 22.13776229783064)
# network: (array([-0.81171024,  0.5011405 ], dtype=float32), array([-1.417699 , -1.5077109], dtype=float32), 18.424198150634766)
# target: (array([-0.5155331 ,  0.23094502], dtype=float32), array([-0.3783749, -1.2969391], dtype=float32), 22.882266236797463)
# network: (array([-0.73096216,  0.47352585], dtype=float32), array([-1.2092865, -1.3774945], dtype=float32), 19.491107940673828)
# target: (array([-0.6705036,  0.5529236], dtype=float32), array([-1.4846501, -1.2861671], dtype=float32), 47.76420449208346)
# network: (array([-0.79322255,  0.29784736], dtype=float32), array([-1.264234, -1.449542], dtype=float32), 35.10014724731445)
# target: (array([-0.77302057,  0.03719788], dtype=float32), array([-1.6637954, -1.2370691], dtype=float32), 55.76416417015758)
# network: (array([-0.7856276 ,  0.35448298], dtype=float32), array([-1.2723632, -1.4637002], dtype=float32), 49.47477722167969)
# target: (array([-0.91623664,  0.27892694], dtype=float32), array([-1.4124242, -1.7548807], dtype=float32), 66.79692824412962)
# network: (array([-0.7812661 ,  0.28099737], dtype=float32), array([-1.2767274, -1.3088819], dtype=float32), 59.66193389892578)
# target: (array([-0.88030785,  0.4489917 ], dtype=float32), array([-1.6179343, -1.7822058], dtype=float32), 74.1864132417968)
# network: (array([-0.822739 ,  0.0927678], dtype=float32), array([-1.5221211, -1.5522857], dtype=float32), 74.8270034790039)
# target: (array([-0.7600053 ,  0.23271313], dtype=float32), array([-1.0783303, -1.5884163], dtype=float32), 77.73559427261355)
# network: (array([-0.74577093, -0.08835903], dtype=float32), array([-1.5466982, -1.5530689], dtype=float32), 84.60315704345703)
# target: (array([-0.89454865, -0.08511656], dtype=float32), array([-1.4572803, -1.7618442], dtype=float32), 88.08239062606896)
# network: (array([-0.7709    ,  0.07970583], dtype=float32), array([-1.3928944, -1.4529257], dtype=float32), 89.004638671875)
# target: (array([-0.81412876, -0.22120541], dtype=float32), array([-1.6259173, -1.3098891], dtype=float32), 93.7977763443363)
# network: (array([-0.7747595 ,  0.21029624], dtype=float32), array([-1.3328246, -1.4785829], dtype=float32), 94.4384765625)
# target: (array([-0.67787194,  0.3278213 ], dtype=float32), array([-1.6783602, -1.5415382], dtype=float32), 96.9468746425812)
# network: (array([-0.7693415 ,  0.16592428], dtype=float32), array([-1.4045776, -1.6342902], dtype=float32), 98.39839935302734)
# target: (array([-0.8799221 ,  0.12535532], dtype=float32), array([-1.2047324, -1.4844843], dtype=float32), 98.12499667320738)

# %%
print("---")
# Out:
# ---
